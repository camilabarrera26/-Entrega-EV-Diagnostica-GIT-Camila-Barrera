# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download prathamsharma123/farmers-protest-tweets-dataset-raw-json
# Out:
# ...
#   0%|          | 0.00/191M [00:00<?, ?B/s]
#   1%|          | 1.00M/191M [00:00<00:56, 3.50MB/s]
#   1%|1         | 2.00M/191M [00:00<00:46, 4.31MB/s]
#   2%|1         | 3.00M/191M [00:00<00:52, 3.74MB/s]
#   2%|2         | 4.00M/191M [00:01<00:50, 3.88MB/s]
#   3%|2         | 5.00M/191M [00:01<00:47, 4.09MB/s]
#   3%|3         | 6.00M/191M [00:01<00:43, 4.48MB/s]
#   4%|3         | 7.00M/191M [00:01<00:41, 4.70MB/s]
#   4%|4         | 8.00M/191M [00:01<00:41, 4.68MB/s]
#   5%|4         | 9.00M/191M [00:02<00:42, 4.52MB/s]
#   5%|5         | 10.0M/191M [00:02<00:40, 4.68MB/s]
#   6%|5         | 11.0M/191M [00:02<00:38, 4.96MB/s]
#   6%|6         | 12.0M/191M [00:02<00:35, 5.30MB/s]
#   7%|6         | 13.0M/191M [00:02<00:36, 5.05MB/s]
#   7%|7         | 14.0M/191M [00:03<00:38, 4.81MB/s]
#   8%|7         | 15.0M/191M [00:03<00:40, 4.54MB/s]
#   8%|8         | 16.0M/191M [00:03<00:35, 5.19MB/s]
#   9%|8         | 17.0M/191M [00:03<00:34, 5.32MB/s]
# ...

# %%
import pandas as pd

# %%
pd.read_json('farmers-protest-tweets-dataset-raw-json/farmers-protest-tweets-2021-03-5.json', lines=True)
# Out:
#                                                       url  \
# 0       https://twitter.com/ShashiRajbhar6/status/1376...
# 1       https://twitter.com/kaursuk06272818/status/137...
# 2       https://twitter.com/kaursuk06272818/status/137...
# 3       https://twitter.com/SukhdevSingh_/status/13767...
# 4       https://twitter.com/Davidmu66668113/status/137...
# ...                                                   ...
# 419502  https://twitter.com/TeamSOOUDA/status/13560306...
# 419503  https://twitter.com/VibhaBurman/status/1356030...
# 419504  https://twitter.com/NavJammu/status/1356029858...
# 419505  https://twitter.com/Atwal72/status/13560296726...
# 419506  https://twitter.com/Manjind22050118/status/135...
#
#                             date  \
# 0      2021-03-30 03:33:46+00:00
# 1      2021-03-30 03:33:23+00:00
# 2      2021-03-30 03:31:00+00:00
# 3      2021-03-30 03:30:45+00:00
# 4      2021-03-30 03:30:30+00:00
# ...                          ...
# ...

# %%
data = pd.read_json('farmers-protest-tweets-dataset-raw-json/farmers-protest-tweets-2021-03-5.json', lines=True)

# %%
print(data.head())
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %%
from functions import most_retweeted

# %%
most_retweeted(data)
# Out:
#                                                       url  \
# 408128  https://twitter.com/rihanna/status/13566258896...
# 395142  https://twitter.com/GretaThunberg/status/13566...
# 266196  https://twitter.com/GretaThunberg/status/13572...
# 366579  https://twitter.com/miakhalifa/status/13568483...
# 372793  https://twitter.com/miakhalifa/status/13568277...
# 314192  https://twitter.com/TeamJuJu/status/1357048037...
# 215034  https://twitter.com/BobBlackman/status/1357755...
# 398011  https://twitter.com/vanessa_vash/status/135668...
# 325261  https://twitter.com/kylekuzma/status/135700972...
# 163689  https://twitter.com/AmandaCerny/status/1359013...
#
#                             date  \
# 408128 2021-02-02 15:29:51+00:00
# 395142 2021-02-02 20:04:01+00:00
# 266196 2021-02-04 10:59:01+00:00
# 366579 2021-02-03 06:14:01+00:00
# 372793 2021-02-03 04:51:48+00:00
# 314192 2021-02-03 19:27:19+00:00
# 215034 2021-02-05 18:19:19+00:00
# 398011 2021-02-02 19:09:23+00:00
# ...

# %%
from functions import most_tweets_user

# %%
most_tweets_user(data)
# Out:
# harjot_tweeting
# tasveersandhu
# shells_n_petals
# jot__b
# rebelpacifist
# rumsomal
# Iamjazzie96
# Jass_k_G
# DigitalKisanBot
# z_khalique007

# %%
from functions import most_tweets_day

# %%
most_tweets_day(data)
# Out:
# 2021-02-03
# 2021-02-04
# 2021-02-05
# 2021-02-02
# 2021-02-06
# 2021-02-07
# 2021-02-09
# 2021-02-08
# 2021-02-10
# 2021-02-11

# %%
from functions import most_used_hashtag

# %%
most_used_hashtag(data)
# Out:
# FarmersProtest
# IStandWithFarmers
# farmersprotest
# IndianFarmersHumanRights
# FarmersAreIndia
# StandWithFarmers
# Rihanna
# FarmersProtests
# Farmers
# shameonbollywood
